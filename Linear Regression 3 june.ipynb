# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data={
"Hours":[2,3,4,5,6,7 ],
"Marks":[55,67,72,83,89,93]
     }

# %%
df = pd.DataFrame(columns=["Hours","Marks"])

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Hours  Marks
# 0      2     55
# 1      3     67
# 2      4     72
# 3      5     83
# 4      6     89
# 5      7     93

# %%
plt.scatter(Hours,Marks)

# %%
import seaborn as sns

# %%
sns.regplot(x = Hours ,y=Marks)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

# %%
Hours = df[["Hours"]]
Marks = df["Marks"]

# %%
reg = LinearRegression()

# %%
reg.fit(Hours,Marks)
# Out:
# LinearRegression()

# %%
reg.predict(Hours)
# Out:
# array([57.42857143, 65.05714286, 72.68571429, 80.31428571, 87.94285714,
#        95.57142857])

# %%
import pickle as pkl

# %%
pkl.dump(reg,open('a.pkl','wb'))
