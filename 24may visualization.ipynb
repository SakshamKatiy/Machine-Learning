# %%
import pandas as pd

# %%
df = pd.read_csv('foot.csv')

# %%
df.head()
# Out:
#                                                 name  \
# 0  Women's Casual Sports Shoes, Fashionable Versa...
# 1  2024 New Spring/Autumn Women Breathable Mesh H...
# 2  Women's Casual Slip-on Flat Skate Shoes With A...
# 3  Women Mesh Breathable Casual Shoes, Soft Non-S...
# 4                Women's Fashionable Casual Sneakers
#
#                                                 link  price_usd  \
# 0  https://us.shein.com/Women-s-Casual-Sports-Sho...      19.40
# 1  https://us.shein.com/2024-New-Spring-Autumn-Wo...      14.90
# 2  https://us.shein.com/Women-s-Casual-Slip-on-Fl...       7.50
# 3  https://us.shein.com/Women-Mesh-Breathable-Cas...      12.06
# 4  https://us.shein.com/Women-s-Fashionable-Casua...      13.53
#
#    mark_price_usd  star_rating  colour      seller_name review_count  \
# 0           24.40         4.83   Khaki     Womens Shoes           77
# 1           18.80         0.00     NaN  Limeiya Factory            0
# ...

# %%
import matplotlib.pyplot as plt

# %%
x = ['sak','sam','saksham']
y = [12,24,54]

# %%
plt.title("This is Line Plot",color="m")
plt.plot(x,y)

# %%
x = df['seller_name']
y = df['mark_price_usd']

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 899 artists>

# %%
x=['saksham','katiyar','sak','aryan','ashuone']
y=[23,43,12,34,53]

# %%
plt.figure(figsize=(10,6))
df1 = plt.bar(x,y)
plt.ylabel('Marks')
plt.xlabel("Students")
plt.title("Adit Marks",{'color':'red','size':20,'family':"serif"})
plt.grid(color='green',linestyle='-')

# %%
plt.pie(y,labels=['saksham','katr','sak','aryan','ashuone'],colors = ['cyan','magenta','pink','yellow'],radius=1.5,startangle=90,counterclock=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x2078a8c2e60>,
# ...
#  [Text(0.6996919668748081, 1.4942995521283082, 'saksham'),
#   Text(1.6373800406615489, -0.20368260221036405, 'katr'),
#   Text(0.6422957717989292, -1.5198539869109857, 'sak'),
#   Text(-0.7560736443439315, -1.4665785503437878, 'aryan'),
#   Text(-1.3964977676525543, 0.8788025858754814, 'ashuone')])

# %%
x = [2,3,4.5,6,4,2.1]
y = [4,2,5.6,4,3,2]

# %%
plt.scatter(x,y)

# %%
plt.boxplot(x,showcaps=False,showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2078b35c100>,
# ...
#  'caps': [],
#  'boxes': [<matplotlib.lines.Line2D at 0x2078b333e20>],
#  'medians': [<matplotlib.lines.Line2D at 0x2078b35c640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2078b35cb80>],
#  'means': [<matplotlib.lines.Line2D at 0x2078b35c8e0>]}

# %%
plt.violinplot([2,3,4.5,6,4,2.1],vert=False,showmeans=True,showmedians=True,quantiles=[1,4])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 plt.violinplot([2,3,4.5,6,4,2.1],vert=False,showmeans=True,showmedians=True,quantiles=[1,4])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:3045, in violinplot(dataset, positions, vert, widths, showmeans, showextrema, showmedians, quantiles, points, bw_method, data)
#    3040 @_copy_docstring_and_deprecators(Axes.violinplot)
#    3041 def violinplot(
#    3042         dataset, positions=None, vert=True, widths=0.5,
#    3043         showmeans=False, showextrema=True, showmedians=False,
#    3044         quantiles=None, points=100, bw_method=None, *, data=None):
# -> 3045     return gca().violinplot(
#    3046         dataset, positions=positions, vert=vert, widths=widths,
#    3047         showmeans=showmeans, showextrema=showextrema,
# ...
